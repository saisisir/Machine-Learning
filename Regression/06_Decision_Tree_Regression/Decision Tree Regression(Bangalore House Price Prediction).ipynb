# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv(r"C:\Users\sisir.sahu\Downloads\Sisir's macbook\Self Learning2\Machine Learning\Kaggle Practice\6. Decision Tree Regression\bangalore house price prediction OHE-data.csv")

# %%
data.head()
# Out:
#    bath  balcony  price  total_sqft_int  bhk  price_per_sqft  \
# 0   3.0      2.0  150.0          1672.0    3     8971.291866
# 1   3.0      3.0  149.0          1750.0    3     8514.285714
# 2   3.0      2.0  150.0          1750.0    3     8571.428571
# 3   2.0      2.0   40.0          1250.0    2     3200.000000
# 4   2.0      2.0   83.0          1200.0    2     6916.666667
#
#    area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                              1                        0
# 1                              0                        1
# 2                              1                        0
# 3                              1                        0
# 4                              0                        0
#
#    area_typePlot  Area  availability_Ready To Move  ...  \
# 0                    0                           1  ...
# 1                    0                           1  ...
# 2                    0                           1  ...
# ...

# %%
x = data.drop('price', axis = 1)
y = data['price']

# %%
x.head()
# Out:
#    bath  balcony  total_sqft_int  bhk  price_per_sqft  \
# 0   3.0      2.0          1672.0    3     8971.291866
# 1   3.0      3.0          1750.0    3     8514.285714
# 2   3.0      2.0          1750.0    3     8571.428571
# 3   2.0      2.0          1250.0    2     3200.000000
# 4   2.0      2.0          1200.0    2     6916.666667
#
#    area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                              1                        0
# 1                              0                        1
# 2                              1                        0
# 3                              1                        0
# 4                              0                        0
#
#    area_typePlot  Area  availability_Ready To Move  location_Whitefield  ...  \
# 0                    0                           1                    0  ...
# 1                    0                           1                    0  ...
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

# %%
regressor = DecisionTreeRegressor(max_depth = 4)

# %%
regressor.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=4)

# %%
y_pred = regressor.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)

# %%
mse
# Out:
# 2105.8275245454965

# %%
# Print the predicted prices and MSE
print("Predicted Prices:", predicted_prices)
print("Mean Squared Error (MSE):", mse)
# Out:
# Predicted Prices: [50.08614829 50.08614829 50.08614829 ... 50.08614829 50.08614829
#  50.08614829]
# Mean Squared Error (MSE): 2105.8275245454965

# %%
from sklearn.metrics import r2_score, mean_squared_error

#mean squared error and root mean squared error of linear model
r_square_lr = r2_score(y_test, y_pred)
r_square_lr
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 2105.8275245454965

# %%
print(r_square_lr*100,'%')
# Out:
# 81.45160075409173 %

# %%
y_pred
# Out:
# array([50.08614829, 50.08614829, 50.08614829, ..., 50.08614829,
#        50.08614829, 50.08614829])
